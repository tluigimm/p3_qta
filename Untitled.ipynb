# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel ('./RelatorioQualidadeAguasSuperficiais.xlsx')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Período DE Período ATE  Cod_Interaguas    Tipo Rede            UGRHI  \
# 0  01/01/2016  01/01/2021             136  Rede Básica  06 - ALTO TIÊTE
# 1  01/01/2016  01/01/2021             136  Rede Básica  06 - ALTO TIÊTE
# 2  01/01/2016  01/01/2021             136  Rede Básica  06 - ALTO TIÊTE
# 3  01/01/2016  01/01/2021             136  Rede Básica  06 - ALTO TIÊTE
# 4  01/01/2016  01/01/2021             136  Rede Básica  06 - ALTO TIÊTE
#
#   Código Ponto Status Ponto Data Coleta Hora Coleta Parametro Sinal  \
# 0    PINH04100        Ativo  28/01/2016       11:18        pH   NaN
# 1    PINH04100        Ativo  30/03/2016       11:45        pH   NaN
# 2    PINH04100        Ativo  19/05/2016       12:01        pH   NaN
# 3    PINH04100        Ativo  13/07/2016       12:30        pH   NaN
# 4    PINH04100        Ativo  14/09/2016       12:00        pH   NaN
#
#         Valor Unidade Tipo Parâmetro       Sistema Hídrico  \
# 0  7,28000000    U.pH    3- Químicos  Rio Pinheiros - PINH
# 1  7,01000000    U.pH    3- Químicos  Rio Pinheiros - PINH
# 2  7,06000000    U.pH    3- Químicos  Rio Pinheiros - PINH
# 3  6,79000000    U.pH    3- Químicos  Rio Pinheiros - PINH
# 4  6,49000000    U.pH    3- Químicos  Rio Pinheiros - PINH
#
#   Tipo de Sistema Hídrico    CLASSE  Município  UF Inicio Operação  \
# 0            Rio (Lótico)  Classe 4  SÃO PAULO  SP      01/01/1977
# 1            Rio (Lótico)  Classe 4  SÃO PAULO  SP      01/01/1977
# 2            Rio (Lótico)  Classe 4  SÃO PAULO  SP      01/01/1977
# 3            Rio (Lótico)  Classe 4  SÃO PAULO  SP      01/01/1977
# 4            Rio (Lótico)  Classe 4  SÃO PAULO  SP      01/01/1977
#
#    Fim Operação   Latitude  Longitude  Altitude  \
# 0           NaN  23 42 09   46 40 26        774
# 1           NaN  23 42 09   46 40 26        774
# 2           NaN  23 42 09   46 40 26        774
# 3           NaN  23 42 09   46 40 26        774
# 4           NaN  23 42 09   46 40 26        774
#
#                                          Localização Captação
# 0  Na Usina Elevatória de Pedreira, no centro do ...        N
# 1  Na Usina Elevatória de Pedreira, no centro do ...        N
# 2  Na Usina Elevatória de Pedreira, no centro do ...        N
# 3  Na Usina Elevatória de Pedreira, no centro do ...        N
# 4  Na Usina Elevatória de Pedreira, no centro do ...        N

# %%
amostras_PH = {'00': []}

for date in df['Data Coleta']:
    m = date[3:5]
    y = date[6:]
    for key in amostras_PH:
        if key != m + y:
            amostras[m+y] = [df['Valor'][str(date.index)]]
        else:
            amostras[x+y].append(df['Valor'][date.index])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ee1b3b368046> in <module>
#       6     for key in amostras_PH:
#       7         if key != m + y:
# ----> 8             amostras[m+y] = [df['Valor'][str(date.index)]]
#       9         else:
#      10             amostras[x+y].append(df['Valor'][date.index])
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: '<built-in method index of str object at 0x7f3f6236b0f0>'
